# %%
import numpy as np

# %%
patterns = []
with open("day17.txt") as f:
    lines = f.readlines()
current_pattern = []
for line in lines:
    if len(line) > 3:
        line = line[:-1]
        current_pattern.append(line)
    else:
        patterns.append(current_pattern)
        current_pattern = []
patterns.append(current_pattern)
patterns[0]
#beware - new line must be at input
pattern = patterns[0]
x_dim = len(pattern[0])
y_dim = len(pattern)
x_dim, y_dim
symbols = np.zeros((y_dim, x_dim), dtype="int")
numbers = []
for y, row in enumerate(pattern):
    for x, val in enumerate(row):
        symbols[y, x] = int(val)

# %%
def pretty_print(matrix):
    print(str(matrix).replace(' ','').replace("'","").replace('[','').replace(']',''))

# %%
pretty_print(symbols)
# Out:
# 111111111111
# 999999999991
# 999999999991
# 999999999991
# 999999999991

# %%
from queue import PriorityQueue

# %%
class LavaNode():
    def __init__(self, y, x, direction, charges, cost) -> None:
        self.x = x
        self.y = y
        self.direction = direction
        self.charges = charges
        self.cost = cost

    def __repr__(self) -> str:
        return f"{self.y=} {self.x=} {self.cost=} {self.charges=} {self.direction=}"
    
    def __lt__(self, other):
        if self.charges != self.charges:
            return self.charges < other.charges
        if self.x == other.x:
            return self.y < other.y
        return self.x < other.x

# %%
queue = PriorityQueue()
cost_right = symbols[0, 1]
queue.put((cost_right, LavaNode(0, 1, 'R', 1, cost_right)))
cost_down =  symbols[1, 0]
processed_nodes = dict()
queue.put((cost_down, LavaNode(1, 0, "D", 1, cost_down)))

while not queue.empty():
    next_priority, next_data = queue.get() 
    if (next_data.y, next_data.x, next_data.charges, next_data.direction) not in processed_nodes:
        if next_data.x == x_dim - 1 and next_data.y == y_dim - 1:
            print(next_data)
        processed_nodes[(next_data.y, next_data.x, next_data.charges, next_data.direction)] = next_data.cost
        # we will need to handle other charges as well
        #if next_data.charges == 1 and :
        if next_data.charges > 3:
            if next_data.direction in ["U", "D"]:
                if next_data.x +1 < x_dim:
                    cost_right = symbols[next_data.y, next_data.x + 1] + next_data.cost
                    queue.put((cost_right, LavaNode(next_data.y, next_data.x + 1, 'R', 1, cost_right)))
                if next_data.x > 0:
                    cost_left =  symbols[next_data.y, next_data.x - 1] + next_data.cost
                    queue.put((cost_left, LavaNode(next_data.y, next_data.x - 1, "L", 1, cost_left)))
            elif next_data.direction in ["L", "R"]:
                if next_data.y > 0:
                    cost_up = symbols[next_data.y -1, next_data.x] + next_data.cost
                    queue.put((cost_up, LavaNode(next_data.y - 1, next_data.x, 'U', 1, cost_up)))
                if next_data.y + 1 < y_dim:
                    cost_down =  symbols[next_data.y + 1, next_data.x] + next_data.cost
                    queue.put((cost_down, LavaNode(next_data.y + 1, next_data.x, "D", 1, cost_down)))
        if next_data.charges < 10:
            if next_data.direction == "R":
                 if next_data.x +1 < x_dim:
                    cost_right = symbols[next_data.y, next_data.x + 1] + next_data.cost
                    queue.put((cost_right, LavaNode(next_data.y, next_data.x + 1, 'R', next_data.charges + 1, cost_right)))
            elif next_data.direction == "L":
                   if next_data.x > 0:
                        cost_left =  symbols[next_data.y, next_data.x - 1] + next_data.cost
                        queue.put((cost_left, LavaNode(next_data.y, next_data.x - 1, "L", next_data.charges + 1, cost_left)))
            elif next_data.direction == "U":
                 if next_data.y > 0:
                    cost_up = symbols[next_data.y -1, next_data.x] + next_data.cost
                    queue.put((cost_up, LavaNode(next_data.y - 1, next_data.x, 'U', next_data.charges + 1, cost_up)))
            elif next_data.direction == "D":
                 if next_data.y + 1 < y_dim:
                    cost_down =  symbols[next_data.y + 1, next_data.x] + next_data.cost
                    queue.put((cost_down, LavaNode(next_data.y + 1, next_data.x, "D", next_data.charges + 1, cost_down)))
# Out:
# self.y=4 self.x=11 self.cost=47 self.charges=1 self.direction='R'
# self.y=4 self.x=11 self.cost=55 self.charges=2 self.direction='R'
# self.y=4 self.x=11 self.cost=63 self.charges=3 self.direction='R'
# self.y=4 self.x=11 self.cost=71 self.charges=4 self.direction='R'
# self.y=4 self.x=11 self.cost=79 self.charges=5 self.direction='R'
# self.y=4 self.x=11 self.cost=87 self.charges=6 self.direction='R'
# self.y=4 self.x=11 self.cost=95 self.charges=7 self.direction='R'
# self.y=4 self.x=11 self.cost=111 self.charges=4 self.direction='D'
# self.y=4 self.x=11 self.cost=183 self.charges=8 self.direction='R'
# self.y=4 self.x=11 self.cost=193 self.charges=9 self.direction='R'
# self.y=4 self.x=11 self.cost=203 self.charges=10 self.direction='R'

# %%
processed_nodes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [64], line 1
# ----> 1 processed_nodes()
#
# TypeError: 'dict' object is not callable

# %%
processed_nodes
# Out:
# {(0, 1, 1, 'R'): 1,
#  (0, 2, 2, 'R'): 2,
#  (0, 3, 3, 'R'): 3,
#  (0, 4, 4, 'R'): 4,
#  (0, 5, 5, 'R'): 5,
#  (0, 6, 6, 'R'): 6,
#  (0, 7, 7, 'R'): 7,
#  (0, 8, 8, 'R'): 8,
#  (1, 0, 1, 'D'): 9,
#  (0, 9, 9, 'R'): 9,
#  (0, 10, 10, 'R'): 10,
#  (1, 4, 1, 'D'): 13,
#  (1, 5, 1, 'D'): 14,
#  (1, 6, 1, 'D'): 15,
#  (1, 7, 1, 'D'): 16,
#  (1, 8, 1, 'D'): 17,
#  (2, 0, 2, 'D'): 18,
#  (1, 9, 1, 'D'): 18,
#  (1, 10, 1, 'D'): 19,
#  (2, 4, 2, 'D'): 22,
#  (2, 5, 2, 'D'): 23,
#  (2, 6, 2, 'D'): 24,
#  (2, 7, 2, 'D'): 25,
#  (2, 8, 2, 'D'): 26,
#  (3, 0, 3, 'D'): 27,
#  (2, 9, 2, 'D'): 27,
#  (2, 10, 2, 'D'): 28,
#  (3, 4, 3, 'D'): 31,
#  (3, 5, 3, 'D'): 32,
#  (3, 6, 3, 'D'): 33,
#  (3, 7, 3, 'D'): 34,
#  (3, 8, 3, 'D'): 35,
#  (4, 0, 4, 'D'): 36,
#  (3, 9, 3, 'D'): 36,
#  (3, 10, 3, 'D'): 37,
#  (4, 4, 4, 'D'): 40,
#  (4, 5, 4, 'D'): 41,
#  (4, 6, 4, 'D'): 42,
#  (4, 7, 4, 'D'): 43,
#  (4, 8, 4, 'D'): 44,
#  (4, 1, 1, 'R'): 45,
#  (4, 9, 4, 'D'): 45,
#  (4, 10, 4, 'D'): 46,
#  (4, 11, 1, 'R'): 46,
#  (4, 3, 1, 'L'): 49,
#  (4, 5, 1, 'R'): 49,
#  (4, 4, 1, 'L'): 50,
#  (4, 6, 1, 'R'): 50,
#  (4, 5, 1, 'L'): 51,
#  (4, 7, 1, 'R'): 51,
#  (4, 6, 1, 'L'): 52,
#  (4, 8, 1, 'R'): 52,
#  (4, 7, 1, 'L'): 53,
#  (4, 9, 1, 'R'): 53,
#  (4, 2, 2, 'R'): 54,
#  (4, 8, 1, 'L'): 54,
#  (4, 10, 1, 'R'): 54,
#  (4, 11, 2, 'R'): 54,
#  (4, 9, 1, 'L'): 55,
#  (4, 2, 2, 'L'): 58,
#  (4, 6, 2, 'R'): 58,
#  (4, 3, 2, 'L'): 59,
#  (4, 7, 2, 'R'): 59,
#  (4, 4, 2, 'L'): 60,
#  (4, 8, 2, 'R'): 60,
#  (4, 5, 2, 'L'): 61,
#  (4, 9, 2, 'R'): 61,
#  (4, 6, 2, 'L'): 62,
#  (4, 10, 2, 'R'): 62,
#  (4, 11, 3, 'R'): 62,
#  (4, 3, 3, 'R'): 63,
#  (4, 7, 2, 'L'): 63,
#  (4, 8, 2, 'L'): 64,
#  (4, 1, 3, 'L'): 67,
#  (4, 7, 3, 'R'): 67,
#  (4, 2, 3, 'L'): 68,
#  (4, 8, 3, 'R'): 68,
#  (4, 3, 3, 'L'): 69,
#  (4, 9, 3, 'R'): 69,
#  (4, 4, 3, 'L'): 70,
#  (4, 10, 3, 'R'): 70,
#  (4, 11, 4, 'R'): 70,
#  (4, 5, 3, 'L'): 71,
#  (3, 11, 1, 'U'): 71,
#  (4, 4, 4, 'R'): 72,
#  (4, 6, 3, 'L'): 72,
#  (2, 11, 2, 'U'): 72,
#  (4, 7, 3, 'L'): 73,
#  (1, 11, 3, 'U'): 73,
#  (0, 11, 4, 'U'): 74,
#  (0, 10, 1, 'L'): 75,
#  (4, 0, 4, 'L'): 76,
#  (4, 8, 4, 'R'): 76,
#  (0, 9, 2, 'L'): 76,
#  (4, 1, 4, 'L'): 77,
#  (0, 8, 3, 'L'): 77,
#  (4, 9, 4, 'R'): 77,
#  (4, 2, 4, 'L'): 78,
#  (0, 7, 4, 'L'): 78,
#  (4, 10, 4, 'R'): 78,
#  (4, 11, 5, 'R'): 78,
#  (4, 3, 4, 'L'): 79,
#  (0, 6, 5, 'L'): 79,
#  (4, 4, 4, 'L'): 80,
#  (0, 5, 6, 'L'): 80,
#  (0, 4, 7, 'L'): 81,
#  (3, 4, 1, 'U'): 81,
#  (4, 5, 5, 'R'): 81,
#  (4, 5, 4, 'L'): 81,
#  (0, 3, 8, 'L'): 82,
#  (4, 6, 4, 'L'): 82,
#  (0, 2, 9, 'L'): 83,
#  (0, 1, 10, 'L'): 84,
#  (3, 0, 1, 'U'): 85,
#  (3, 8, 1, 'U'): 85,
#  (4, 9, 5, 'R'): 85,
#  (4, 0, 5, 'L'): 86,
#  (3, 1, 1, 'U'): 86,
#  (3, 9, 1, 'U'): 86,
#  (4, 10, 5, 'R'): 86,
#  (4, 11, 6, 'R'): 86,
#  (4, 1, 5, 'L'): 87,
#  (3, 2, 1, 'U'): 87,
#  (3, 10, 1, 'U'): 87,
#  (4, 2, 5, 'L'): 88,
#  (3, 3, 1, 'U'): 88,
#  (4, 3, 5, 'L'): 89,
#  (2, 4, 2, 'U'): 90,
#  (4, 4, 5, 'L'): 90,
#  (3, 5, 1, 'U'): 90,
#  (4, 6, 6, 'R'): 90,
#  (1, 3, 1, 'D'): 91,
#  (4, 5, 5, 'L'): 91,
#  (3, 6, 1, 'U'): 91,
#  (1, 2, 1, 'D'): 92,
#  (1, 1, 1, 'D'): 93,
#  (2, 0, 2, 'U'): 94,
#  (2, 8, 2, 'U'): 94,
#  (4, 10, 6, 'R'): 94,
#  (4, 11, 7, 'R'): 94,
#  (2, 1, 2, 'U'): 95,
#  (2, 9, 2, 'U'): 95,
#  (4, 0, 6, 'L'): 96,
#  (2, 2, 2, 'U'): 96,
#  (2, 10, 2, 'U'): 96,
#  (4, 1, 6, 'L'): 97,
#  (2, 3, 2, 'U'): 97,
#  (4, 2, 6, 'L'): 98,
#  (4, 3, 6, 'L'): 99,
#  (1, 4, 3, 'U'): 99,
#  (2, 5, 2, 'U'): 99,
#  (4, 7, 7, 'R'): 99,
#  (2, 3, 2, 'D'): 100,
#  (0, 4, 4, 'U'): 100,
#  (4, 4, 6, 'L'): 100,
#  (2, 6, 2, 'U'): 100,
#  (2, 2, 2, 'D'): 101,
#  (0, 3, 1, 'L'): 101,
#  (0, 5, 1, 'R'): 101,
#  (2, 1, 2, 'D'): 102,
#  (0, 2, 2, 'L'): 102,
#  (0, 6, 2, 'R'): 102,
#  (1, 0, 3, 'U'): 103,
#  (0, 1, 3, 'L'): 103,
#  (0, 7, 3, 'R'): 103,
#  (1, 8, 3, 'U'): 103,
#  (0, 0, 4, 'U'): 104,
#  (0, 0, 4, 'L'): 104,
#  (1, 1, 3, 'U'): 104,
#  (0, 8, 4, 'R'): 104,
#  (0, 8, 4, 'U'): 104,
#  (1, 9, 3, 'U'): 104,
#  (0, 1, 4, 'U'): 105,
#  (1, 2, 3, 'U'): 105,
#  (0, 7, 1, 'L'): 105,
#  (0, 9, 1, 'R'): 105,
#  (0, 9, 4, 'U'): 105,
#  (0, 9, 5, 'R'): 105,
#  (1, 10, 3, 'U'): 105,
#  (0, 0, 1, 'L'): 106,
#  (4, 0, 7, 'L'): 106,
#  (0, 2, 4, 'U'): 106,
#  (0, 2, 1, 'R'): 106,
#  (1, 3, 3, 'U'): 106,
#  (0, 6, 2, 'L'): 106,
#  (0, 8, 1, 'L'): 106,
#  (0, 10, 6, 'R'): 106,
#  (0, 10, 4, 'U'): 106,
#  (0, 10, 1, 'R'): 106,
#  (0, 10, 2, 'R'): 106,
#  (0, 1, 1, 'L'): 107,
#  (4, 1, 7, 'L'): 107,
#  (0, 3, 2, 'R'): 107,
#  (0, 3, 1, 'R'): 107,
#  (0, 3, 4, 'U'): 107,
#  (0, 5, 3, 'L'): 107,
#  (0, 7, 2, 'L'): 107,
#  (0, 9, 1, 'L'): 107,
#  (0, 11, 1, 'R'): 107,
#  (0, 11, 2, 'R'): 107,
#  (0, 11, 7, 'R'): 107,
#  (0, 11, 3, 'R'): 107,
#  (0, 0, 2, 'L'): 108,
#  (0, 2, 1, 'L'): 108,
#  (4, 2, 7, 'L'): 108,
#  (0, 4, 1, 'R'): 108,
#  (0, 4, 2, 'R'): 108,
#  (0, 4, 3, 'R'): 108,
#  (0, 4, 4, 'L'): 108,
#  (1, 5, 3, 'U'): 108,
#  (0, 6, 3, 'L'): 108,
#  (3, 7, 1, 'U'): 108,
#  (0, 8, 2, 'L'): 108,
#  (4, 8, 8, 'R'): 108,
#  (1, 11, 1, 'D'): 108,
#  (0, 1, 2, 'L'): 109,
#  (0, 3, 5, 'L'): 109,
#  (3, 3, 3, 'D'): 109,
#  (4, 3, 7, 'L'): 109,
#  (0, 5, 4, 'L'): 109,
#  (0, 5, 4, 'U'): 109,
#  (0, 5, 4, 'R'): 109,
#  (0, 5, 2, 'R'): 109,
#  (0, 5, 3, 'R'): 109,
#  (1, 6, 3, 'U'): 109,
#  (0, 7, 3, 'L'): 109,
#  (2, 11, 2, 'D'): 109,
#  (0, 0, 3, 'L'): 110,
#  (0, 2, 6, 'L'): 110,
#  (3, 2, 3, 'D'): 110,
#  (0, 4, 5, 'L'): 110,
#  (0, 4, 1, 'L'): 110,
#  (0, 6, 1, 'R'): 110,
#  (0, 6, 4, 'U'): 110,
#  (0, 6, 4, 'R'): 110,
#  (0, 6, 4, 'L'): 110,
#  (0, 6, 5, 'R'): 110,
#  (0, 6, 3, 'R'): 110,
#  (3, 11, 3, 'D'): 110,
#  (4, 11, 4, 'D'): 110,
#  (0, 1, 7, 'L'): 111,
#  (3, 1, 3, 'D'): 111,
#  (0, 3, 2, 'L'): 111,
#  (0, 3, 6, 'L'): 111,
#  (0, 5, 1, 'L'): 111,
#  (0, 5, 5, 'L'): 111,
#  (0, 7, 4, 'R'): 111,
#  (0, 7, 2, 'R'): 111,
#  (0, 7, 6, 'R'): 111,
#  (0, 7, 5, 'R'): 111,
#  (0, 7, 1, 'R'): 111,
#  (0, 0, 8, 'L'): 112,
#  (0, 2, 3, 'L'): 112,
#  (0, 2, 7, 'L'): 112,
#  (0, 4, 2, 'L'): 112,
#  (0, 4, 6, 'L'): 112,
#  (0, 8, 5, 'R'): 112,
#  (0, 8, 7, 'R'): 112,
#  (0, 8, 3, 'R'): 112,
#  (0, 8, 6, 'R'): 112,
#  (0, 8, 2, 'R'): 112,
#  (0, 1, 8, 'L'): 113,
#  (0, 1, 4, 'L'): 113,
#  (0, 3, 3, 'L'): 113,
#  (0, 3, 7, 'L'): 113,
#  (0, 9, 7, 'R'): 113,
#  (0, 9, 3, 'R'): 113,
#  (0, 9, 6, 'R'): 113,
#  (0, 9, 4, 'R'): 113,
#  (0, 9, 8, 'R'): 113,
#  (0, 0, 9, 'L'): 114,
#  (0, 0, 5, 'L'): 114,
#  (0, 2, 8, 'L'): 114,
#  (0, 2, 4, 'L'): 114,
#  (0, 10, 5, 'R'): 114,
#  (0, 10, 9, 'R'): 114,
#  (0, 10, 8, 'R'): 114,
#  (0, 10, 7, 'R'): 114,
#  (0, 10, 4, 'R'): 114,
#  (0, 1, 9, 'L'): 115,
#  (0, 1, 5, 'L'): 115,
#  (0, 11, 10, 'R'): 115,
#  (0, 11, 8, 'R'): 115,
#  (0, 11, 9, 'R'): 115,
#  (0, 11, 6, 'R'): 115,
#  (0, 11, 5, 'R'): 115,
#  (0, 0, 6, 'L'): 116,
#  (0, 0, 10, 'L'): 116,
#  (4, 0, 8, 'L'): 116,
#  (4, 1, 8, 'L'): 117,
#  (2, 7, 2, 'U'): 117,
#  (4, 9, 9, 'R'): 117,
#  (4, 2, 8, 'L'): 118,
#  (4, 3, 4, 'D'): 118,
#  (4, 2, 4, 'D'): 119,
#  (4, 10, 1, 'L'): 119,
#  (4, 1, 4, 'D'): 120,
#  (4, 0, 9, 'L'): 126,
#  (1, 7, 3, 'U'): 126,
#  (4, 10, 10, 'R'): 126,
#  (4, 1, 9, 'L'): 127,
#  (4, 2, 1, 'L'): 127,
#  (4, 4, 1, 'R'): 127,
#  (0, 7, 4, 'U'): 127,
#  (4, 1, 1, 'L'): 128,
#  (4, 3, 1, 'R'): 128,
#  (0, 6, 1, 'L'): 128,
#  (0, 8, 1, 'R'): 128,
#  (4, 9, 2, 'L'): 128,
#  (4, 0, 1, 'L'): 129,
#  (4, 2, 1, 'R'): 129,
#  (0, 5, 2, 'L'): 129,
#  (0, 9, 2, 'R'): 129,
#  (0, 4, 3, 'L'): 130,
#  (0, 10, 3, 'R'): 130,
#  (0, 3, 4, 'L'): 131,
#  (0, 11, 4, 'R'): 131,
#  (0, 2, 5, 'L'): 132,
#  (0, 1, 6, 'L'): 133,
#  (0, 0, 7, 'L'): 134,
#  (4, 0, 10, 'L'): 136,
#  (4, 1, 2, 'L'): 136,
#  (4, 5, 2, 'R'): 136,
#  (4, 0, 2, 'L'): 137,
#  (4, 4, 2, 'R'): 137,
#  (4, 8, 3, 'L'): 137,
#  (4, 3, 2, 'R'): 138,
#  (4, 0, 3, 'L'): 145,
#  (4, 6, 3, 'R'): 145,
#  (4, 5, 3, 'R'): 146,
#  (4, 7, 4, 'L'): 146,
#  (4, 4, 3, 'R'): 147,
#  (4, 7, 4, 'R'): 154,
#  (4, 6, 5, 'L'): 155,
#  (4, 6, 4, 'R'): 155,
#  (4, 5, 4, 'R'): 156,
#  (4, 8, 5, 'R'): 163,
#  (4, 5, 6, 'L'): 164,
#  (4, 7, 5, 'R'): 164,
#  (4, 6, 5, 'R'): 165,
#  (4, 9, 6, 'R'): 172,
#  (4, 4, 7, 'L'): 173,
#  (4, 8, 6, 'R'): 173,
#  (4, 7, 6, 'R'): 174,
#  (4, 10, 7, 'R'): 181,
#  (4, 11, 8, 'R'): 181,
#  (4, 3, 8, 'L'): 182,
#  (4, 9, 7, 'R'): 182,
#  (4, 8, 7, 'R'): 183,
#  (4, 2, 9, 'L'): 191,
#  (4, 10, 8, 'R'): 191,
#  (4, 11, 9, 'R'): 191,
#  (4, 9, 8, 'R'): 192,
#  (4, 1, 10, 'L'): 200,
#  (4, 10, 9, 'R'): 201,
#  (4, 11, 10, 'R'): 201}
