# %%
class Pulse():
    def __init__(self, source, destination, is_high) -> None:
        self.source = source
        self.destination = destination
        self.is_high = is_high

    def __repr__(self) -> str:
        return f"{self.source.name if self.source else 'Button'} -{'high' if self.is_high else 'low'}-> {self.destination.name}"

# %%
class FlipFlop():
    def __init__(self, name, destinations) -> None:
        self.is_on = False
        self.name = name
        self.destinations = destinations
        self.type ="flipflop"

    def handle_pulse(self, pulse: Pulse):
        new_pulses = []
        if not pulse.is_high:
            self.is_on = not self.is_on
            for destination in self.destinations:
                new_pulses.append(Pulse(self, destination, self.is_on))
        return new_pulses

# %%
class Broadcaster():
    def __init__(self, name, destinations) -> None:
        self.destinations = destinations
        self.name = name
        self.type ="broadcaster"

    def handle_pulse(self, pulse: Pulse):
        new_pulses = []
        for destination in self.destinations:
            new_pulses.append(Pulse(self, destination, pulse.is_high))
        return new_pulses

# %%
class Conjunction():
    def __init__(self, name, destinations) -> None:
        self.destinations = destinations
        self.name = name
        self.inputs = {}
        self.type ="conjunction"

    def register_input(self, source):
        self.inputs[source.name] = False


    def handle_pulse(self, pulse: Pulse):
        new_pulses = []
        self.inputs[pulse.source.name] = pulse.is_high
        all_true = sum((self.inputs.values())) == len(self.inputs)
        for destination in self.destinations:
            new_pulses.append(Pulse(self, destination, not all_true))
        return new_pulses

# %%
parsing_items = False
with open("day20.txt") as f:
    lines = f.readlines()
nodes = {}
for i, line in enumerate(lines):
    if len(line) > 3:
        if i != len(lines) -1:
            line = line[:-1]
        #print(line)
        destinations = line.split(">")[1].split(",")
        destinations = [dest.strip() for dest in destinations]
        name = line.split()[0][1:]
        if line.startswith("broadcaster"):
            nodes["broadcaster"] = Broadcaster("broadcaster", destinations)
        elif line.startswith("%"):
            nodes[name] = FlipFlop(name, destinations)
        elif line.startswith("&"):
            nodes[name] = Conjunction(name, destinations)

for node in nodes.values():
    node.destinations = [nodes[dest] if dest in nodes else Broadcaster(dest, []) for dest in node.destinations]
    for destination in node.destinations:
        if destination.type == "conjunction":
            destination.register_input(node)

# %%
# there is one conj node before the rx node - with four input. Lets check how often each input cycles on True

# %%
from collections import deque
queue = deque()
button_presses = 0
for i in range(1000000):
    queue.append(Pulse(None, nodes["broadcaster"], False))
    button_presses += 1
    conj_node = nodes["ns"].inputs
    while (len(queue)):
        signal = queue.popleft()
        if signal.destination.name == 'rx' and not signal.is_high:
            break
        if signal.destination.name == "ns" and (conj_node["dc"] or conj_node["rv"] or conj_node["vp"] or conj_node["cq"]):         
            print(f'{button_presses=} {nodes["ns"].inputs}')
        new_signals = signal.destination.handle_pulse(signal)
        for new_signal in new_signals:
            queue.append(new_signal)
    if conj_node["dc"] or conj_node["rv"] or conj_node["vp"] or conj_node["cq"]:         
        print(nodes["ns"].inputs)
    if signal.destination.name == 'rx' and not signal.is_high:
            break
button_presses
# Out:
# button_presses=3797 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=3847 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=3847 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=3847 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=3877 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=3877 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=3877 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=3877 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=3877 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=4051 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=4051 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=4051 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=4051 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=7594 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=7694 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=7694 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=7694 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=7754 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=7754 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=7754 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=7754 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=7754 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=8102 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=8102 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=8102 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=8102 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=8102 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=11391 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=11541 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=11541 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=11541 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=11631 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=11631 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=11631 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=11631 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=11631 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=12153 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=12153 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=12153 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=12153 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=15188 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=15388 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=15388 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=15388 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=15508 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=15508 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=15508 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=15508 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=15508 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=16204 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=16204 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=16204 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=16204 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=16204 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=18985 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=19235 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=19235 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=19235 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=19385 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=19385 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=19385 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=19385 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=19385 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=20255 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=20255 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=20255 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=20255 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=22782 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=23082 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=23082 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=23082 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=23262 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=23262 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=23262 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=23262 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=23262 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=24306 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=24306 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=24306 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=24306 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=24306 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=26579 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=26929 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=26929 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=26929 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=27139 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=27139 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=27139 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=27139 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=27139 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=28357 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=28357 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=28357 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=28357 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=30376 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=30776 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=30776 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=30776 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=31016 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=31016 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=31016 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=31016 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=31016 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=32408 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=32408 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=32408 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=32408 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=32408 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=34173 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=34623 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=34623 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=34623 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=34893 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=34893 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=34893 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=34893 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=34893 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=36459 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=36459 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=36459 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=36459 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=37970 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=38470 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=38470 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=38470 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=38770 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=38770 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=38770 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=38770 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=38770 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=40510 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=40510 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=40510 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=40510 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=40510 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=41767 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=42317 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=42317 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=42317 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=42647 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=42647 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=42647 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=42647 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=42647 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=44561 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=44561 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=44561 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=44561 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=45564 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=46164 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=46164 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=46164 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=46524 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=46524 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=46524 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=46524 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=46524 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=48612 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=48612 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=48612 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=48612 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=48612 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=49361 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=50011 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=50011 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=50011 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=50401 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=50401 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=50401 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=50401 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=50401 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=52663 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=52663 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=52663 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=52663 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=53158 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=53858 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=53858 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=53858 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=54278 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=54278 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=54278 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=54278 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=54278 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=56714 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=56714 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=56714 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=56714 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=56714 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=56955 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=57705 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=57705 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=57705 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=58155 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=58155 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=58155 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=58155 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=58155 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=60752 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=60752 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=60765 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=60765 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=60765 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=60765 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=61552 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=61552 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=61552 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=62032 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=62032 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=62032 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=62032 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=62032 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=64549 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=64549 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=64816 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=64816 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=64816 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=64816 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=64816 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=65399 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=65399 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=65399 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=65909 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=65909 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=65909 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=65909 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=65909 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=68346 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=68346 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=68867 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=68867 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=68867 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=68867 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=69246 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=69246 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=69246 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=69786 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=69786 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=69786 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=69786 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=69786 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=72143 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=72143 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=72918 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=72918 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=72918 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=72918 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=72918 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=73093 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=73093 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=73093 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=73663 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=73663 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=73663 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=73663 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=73663 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=75940 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=75940 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=76940 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=76940 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=76940 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=76940 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=76969 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=76969 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=77540 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=77540 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=77540 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=77540 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=77540 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=79737 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=79737 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=80787 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=80787 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=80787 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=80787 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=81020 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=81020 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=81020 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=81417 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=81417 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=81417 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=81417 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=81417 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=83534 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=83534 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=84634 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=84634 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=84634 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=84634 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=85071 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=85071 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=85294 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=85294 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=85294 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=85294 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=85294 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=87331 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=87331 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=88481 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=88481 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=88481 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=88481 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=89122 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=89122 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=89122 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=89171 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=89171 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=89171 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=89171 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=89171 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=91128 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=91128 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=92328 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=92328 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=92328 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=92328 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=93048 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=93048 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=93048 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=93048 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=93048 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=93048 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=93173 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=93173 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=94925 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=94925 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=96175 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=96175 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=96175 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=96175 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=96925 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=96925 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=96925 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=96925 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=96925 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=96925 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=97224 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=97224 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=98722 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=98722 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=100022 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=100022 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=100022 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=100022 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=100802 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=100802 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=100802 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=100802 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=100802 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=100802 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=101275 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=101275 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=102519 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=102519 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=103869 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=103869 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=103869 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=103869 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=104679 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=104679 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=104679 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=104679 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=104679 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=104679 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=105326 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=105326 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=106316 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=106316 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=107716 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=107716 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=107716 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=107716 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=108556 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=108556 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=108556 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=108556 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=108556 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=108556 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=109377 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=109377 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=110113 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=110113 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=111563 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=111563 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=111563 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=111563 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=112433 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=112433 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=112433 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=112433 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=112433 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=112433 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=113428 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=113428 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=113910 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=113910 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=115410 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=115410 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=115410 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=115410 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=116310 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=116310 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=116310 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=116310 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=116310 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=116310 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=117479 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=117479 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=117707 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=117707 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=119257 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=119257 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=119257 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=119257 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=120187 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=120187 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=120187 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=120187 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=120187 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=120187 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=121504 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=121530 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=121530 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=123104 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=123104 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=123104 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=123104 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=124064 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=124064 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=124064 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=124064 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=124064 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=124064 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=125301 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=125581 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=125581 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=126951 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=126951 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=126951 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=126951 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=127941 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=127941 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=127941 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=127941 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=127941 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=127941 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=129098 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=129632 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=129632 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=130798 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=130798 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=130798 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=130798 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=131818 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=131818 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=131818 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=131818 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=131818 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=131818 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=132895 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=133683 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=133683 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=134645 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=134645 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=134645 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=134645 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=135695 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=135695 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=135695 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=135695 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=135695 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=135695 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=136692 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=137734 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=137734 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=138492 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=138492 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=138492 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=138492 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=139572 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=139572 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=139572 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=139572 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=139572 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=139572 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=140489 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=141785 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=141785 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=142339 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=142339 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=142339 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=142339 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=143449 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=143449 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=143449 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=143449 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=143449 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=143449 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=144286 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=145836 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=145836 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=146186 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=146186 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=146186 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=146186 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=147326 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=147326 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=147326 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=147326 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=147326 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=147326 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=148083 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=149887 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=149887 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=150033 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=150033 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=150033 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=150033 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=151203 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=151203 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=151203 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=151203 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=151203 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=151203 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=151880 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=153880 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=153880 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=153880 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=153938 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=153938 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=153938 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=155080 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=155080 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=155080 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=155080 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=155080 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=155080 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=155677 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=157727 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=157727 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=157727 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=157989 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=157989 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=157989 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=158957 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=158957 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=158957 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=158957 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=158957 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=158957 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=159474 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=161574 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=161574 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=161574 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=162040 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=162040 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=162040 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=162834 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=162834 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=162834 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=162834 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=162834 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=162834 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=163271 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=165421 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=165421 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=165421 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=166091 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=166091 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=166091 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=166711 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=166711 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=166711 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=166711 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=166711 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=166711 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=167068 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=169268 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=169268 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=169268 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=170142 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=170142 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=170142 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=170588 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=170588 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=170588 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=170588 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=170588 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=170588 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=170865 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=173115 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=173115 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=173115 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=174193 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=174193 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=174193 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=174465 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=174465 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=174465 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=174465 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=174465 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=174465 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=174662 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=176962 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=176962 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=176962 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=178244 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=178244 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=178244 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=178342 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=178342 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=178342 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=178342 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=178342 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=178342 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=178459 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=180809 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=180809 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=180809 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=182219 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=182219 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=182219 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=182219 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=182219 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=182256 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=182256 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=182295 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=182295 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=182295 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=182295 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=184656 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=184656 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=184656 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=186053 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=186053 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=186096 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=186096 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=186096 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=186096 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=186096 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=186346 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=186346 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=186346 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=188503 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=188503 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=188503 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=189850 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=189850 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=189973 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=189973 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=189973 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=189973 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=189973 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# ...
# button_presses=942515 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=942515 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=942515 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=942515 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=943883 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=943883 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=943883 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=943883 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=943883 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=945453 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=945453 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=945453 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=945988 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=945988 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=945988 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=945988 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=946362 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=946362 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=946362 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=947934 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=947934 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=947934 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=947934 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=949250 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=949250 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=949250 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=949250 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=949865 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=949865 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=949865 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=949865 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=950209 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=950209 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=950209 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=950209 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=951985 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=951985 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=951985 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=951985 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=951985 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=953047 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=953047 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=953047 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=953742 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=953742 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=953742 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=953742 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=954056 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=954056 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=954056 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=956036 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=956036 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=956036 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=956036 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=956844 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=956844 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=956844 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=956844 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=957619 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=957619 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=957619 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=957619 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=957903 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=957903 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=957903 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=957903 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=960087 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=960087 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=960087 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=960087 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=960087 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=960641 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=960641 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=960641 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=961496 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=961496 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=961496 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=961496 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=961750 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=961750 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=961750 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=964138 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=964138 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=964138 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=964138 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=964438 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=964438 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=964438 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=964438 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=965373 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=965373 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=965373 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=965373 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=965597 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=965597 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=965597 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=965597 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=968189 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=968189 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=968189 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=968189 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=968189 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=968235 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=968235 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=968235 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=969250 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=969250 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=969250 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=969250 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=969444 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=969444 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=969444 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=972032 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=972032 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=972032 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=972240 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=972240 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=972240 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=972240 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=973127 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=973127 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=973127 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=973127 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=973291 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=973291 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=973291 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=973291 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=975829 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=975829 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=976291 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=976291 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=976291 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=976291 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=976291 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=977004 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=977004 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=977004 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=977004 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=977138 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=977138 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=977138 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=979626 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=979626 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=979626 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=980342 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=980342 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=980342 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=980342 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=980881 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=980881 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=980881 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=980881 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=980985 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=980985 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=980985 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=980985 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=983423 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=983423 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=984393 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=984393 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=984393 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=984393 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=984393 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=984758 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=984758 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=984758 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=984758 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=984832 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=984832 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=984832 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=987220 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=987220 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=987220 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=988444 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=988444 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=988444 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=988444 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=988635 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=988635 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=988635 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=988635 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=988679 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=988679 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=988679 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=988679 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=991017 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=991017 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=992495 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=992495 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=992495 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=992495 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=992495 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=992512 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=992512 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=992512 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=992512 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=992526 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=992526 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=992526 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=994814 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=994814 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=994814 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=996373 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=996373 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=996373 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=996373 {'dc': False, 'rv': False, 'vp': True, 'cq': False}
# button_presses=996389 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=996389 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=996389 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=996389 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=996389 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=996389 {'dc': False, 'rv': False, 'vp': False, 'cq': True}
# button_presses=996546 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=996546 {'dc': False, 'rv': True, 'vp': False, 'cq': False}
# button_presses=998611 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# button_presses=998611 {'dc': True, 'rv': False, 'vp': False, 'cq': False}
# 1000000

# %%
cycle_dc = 3797
cycle_rv = 4051
cycle_vp = 3847
cycle_cq = 3877

# %%
from math import lcm
lcm(*[cycle_dc, cycle_rv, cycle_vp, cycle_cq])
# Out:
# 229414480926893
